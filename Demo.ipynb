# %%
from choreography import Choreography
import matplotlib.pyplot as plt
# Out:
# WARNING:absl:No GPU/TPU found, falling back to CPU. (Set TF_CPP_MIN_LOG_LEVEL=0 and rerun for more info.)

# %%
c = Choreography()

# %%
weights = c.get_8_starting_weights()
c.plot_weight(weights)

# %%
w = c.optimize(weights)
# Out:
# Action :  28.651396
# Action :  19.629465
# Action :  18.62023
# Action :  18.460726
# 18.441334 18.440361

# %%
# 5 body examples

c = Choreography(n_body=5)
weights = c.get_8_starting_weights(3)
c.plot_weight(weights)

# %%
w = c.optimize(weights, n_steps=800, optimization_step=0.0001)
# Out:
# Action :  547.489
# Action :  455.1339
# Action :  380.4143
# Action :  319.9447
# Action :  271.07803
# Action :  231.66539
# Action :  199.94188
# Action :  174.45131
# Action :  153.99168
# Action :  137.5757
# Action :  124.40004
# Action :  113.8176
# Action :  105.30965
# Action :  98.45708
# Action :  92.91571
# Action :  88.40036
# Action :  84.67811
# Action :  81.56496
# Action :  78.92075
# Action :  76.64096
# Action :  74.64828
# Action :  72.88538
# Action :  71.309425
# Action :  69.88819
# Action :  68.59714
# Action :  67.417404
# Action :  66.33432
# Action :  65.33633
# Action :  64.414085
# Action :  63.560074
# Action :  62.767887
# Action :  62.03219
# Action :  61.348297
# Action :  60.71208
# Action :  60.119873
# Action :  59.568367
# Action :  59.0545
# Action :  58.57553
# Action :  58.128925
# Action :  57.712376
