# %%
from choreography import Choreography
import matplotlib.pyplot as plt

# %%
c = Choreography()

# %%
weights = c.get_8_starting_weights()
c.plot_weight(weights)

# %%
w = c.optimize(weights)
# Out:
# Action :  53.02438
# Action :  43.364983
# Action :  42.032528
# Action :  41.803978
# Action :  41.758347
# 41.758347 41.75741

# %%
# 5 body examples

c = Choreography(n_body=5)
weights = c.get_8_starting_weights(3)
c.plot_weight(weights)

# %%
w = c.optimize(weights, n_steps=200)
# Out:
# Action :  51.214184
# Action :  47.550644
# Action :  47.214153
# Action :  47.164204
# Action :  47.155502
# Action :  47.15393
# Action :  47.153637
# Action :  47.153584
# Action :  47.153576
# Action :  47.153564
